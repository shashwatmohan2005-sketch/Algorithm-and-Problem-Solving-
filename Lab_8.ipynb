# %% [markdown]
# <a href="https://colab.research.google.com/github/shashwatmohan2005-sketch/Algorithm-and-Problem-Solving-/blob/main/Lab_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Minimum Cost Spanning Tree
# Problem Description:
# A spanning tree of a graph can be defined as a graph with minimal set of edges that connect all vertices. A minimum spanning tree of a graph is a spanning tree of the graph with least weight (where the weight is computed by adding the weights of all the edges in the spanning tree). In general, a graph can have multiple minimum spanning trees. The problem is to find a minimum spanning tree of a graph.

# %% [markdown]
# This implementation uses a dictionary to represent the weighted graph, where the vertices are keys, and the values are dictionaries containing their adjacent vertices and their weights.
#
# Please note that this implementation assumes that the input graph is connected and weighted.
#
# First, let's create a simple graph to demonstrate Prim's algorithm:

# %%
graph = {
    "A": {"B": 10, "C": 15, "D": 20},
    "B": {"A": 10, "C": 12},
    "C": {"A": 15, "B": 12, "D": 18},
    "D": {"A": 20, "C": 18},
}

# %% [markdown]
# Now, let's implement Prim's algorithm:

# %%
def prims(graph):
    nodes = list(graph.keys())
    visited = [nodes[0]]
    edges = []
    total_cost = 0
    while len(visited) < len(nodes):
        min_weight = float('inf')
        u = v = None
        for i in visited:
            for j in graph[i]:
                if j not in visited:
                    if graph[i][j] < min_weight:
                        min_weight = graph[i][j]
                        u = i
                        v = j
        if v is None:
            break
        visited.append(v)
        edges.append((u, v, min_weight))
        total_cost += min_weight
    return edges, total_cost
graph = {
    "A": {"B": 10, "C": 15, "D": 20},
    "B": {"A": 10, "C": 12},
    "C": {"A": 15, "B": 12, "D": 18},
    "D": {"A": 20, "C": 18},
}
mst, min_weight = prims(graph)
print("Minimum Spanning Tree:", mst)
print("Minimum Weight:", min_weight)
# Out:
# Minimum Spanning Tree: [('A', 'B', 10), ('B', 'C', 12), ('C', 'D', 18)]
# Minimum Weight: 40

# %% [markdown]
# Now, let's run the Prim's algorithm on the example graph:
# Keep in mind that this example uses a simple representation of a graph, but for more complex cases, you might want to use a library such as NetworkX to represent and manipulate graphs.

# %%
mst, min_weight = prims(graph)
print("Minimum Spanning Tree: ", mst)
print("Minimum Weight: ", min_weight)
# Out:
# Minimum Spanning Tree:  [('A', 'B', 10), ('B', 'C', 12), ('C', 'D', 18)]
# Minimum Weight:  40

# %% [markdown]
# Take Differnt example of input graph as discussed in lecture slide and use above code to verify the output

# %%
# your sample input of graph
graph = {
    "A": {"B": 1, "C": 5, "D": 2},
    "B": {"A": 8, "C": 9},
    "C": {"A": 6, "B": 7, "D": 3},
    "D": {"A": 20, "C": 18},
}

# %%
#run prims algorithm for sample input
def prims(graph):
    nodes = list(graph.keys())
    visited = [nodes[0]]
    edges = []
    total_cost = 0

    while len(visited) < len(nodes):
        min_weight = float('inf')
        u = v = None

        for i in visited:
            for j in graph[i]:
                if j not in visited:
                    if graph[i][j] < min_weight:
                        min_weight = graph[i][j]
                        u = i
                        v = j

        if v is None:
            break

        visited.append(v)
        edges.append((u, v, min_weight))
        total_cost += min_weight

    return edges, total_cost

mst, min_weight = prims(graph)

print("Minimum Spanning Tree:", mst)
print("Minimum Weight:", min_weight)
# Out:
# Minimum Spanning Tree: [('A', 'B', 1), ('A', 'D', 2), ('A', 'C', 5)]
# Minimum Weight: 8

# %% [markdown]
# Use same apporach for Kruskal's algorithm

# %%
# implement Kruskal's algorithm
class DisjointSet:
    def __init__(self, n):
        self.par = list(range(n))
        self.rk = [0] * n

    def find(self, u):
        if self.par[u] != u:
            self.par[u] = self.find(self.par[u])
        return self.par[u]

    def union(self, u, v):
        root_u = self.find(u)
        root_v = self.find(v)

        if root_u == root_v:
            return False
        if self.rk[root_u] < self.rk[root_v]:
            self.par[root_u] = root_v
        elif self.rk[root_u] > self.rk[root_v]:
            self.par[root_v] = root_u
        else:
            self.par[root_v] = root_u
            self.rk[root_u] += 1

        return True


def kruskal(n, edges):
    edges.sort(key=lambda x: x[2])

    ds = DisjointSet(n)
    mst = []
    total_weight = 0

    for u, v, w in edges:
        if ds.union(u, v):
            mst.append((u, v, w))
            total_weight += w

    return mst, total_weight
if __name__ == "__main__":
    n = 4
    edges = [
        (0, 1, 10),
        (0, 2, 6),
        (0, 3, 5),
        (1, 3, 15),
        (2, 3, 4)
    ]

    mst, weight = kruskal(n, edges)

    print("Edges in MST:", mst)
    print("Total weight:", weight)
# Out:
# Edges in MST: [(2, 3, 4), (0, 3, 5), (0, 1, 10)]
# Total weight: 19
